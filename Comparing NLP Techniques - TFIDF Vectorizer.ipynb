# %% [markdown]
# ## TFIDF Vectorizer and Random Forest Model

# %%
# Importing all the required libraries

import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score

pd.set_option('display.max_colwidth', 100)

# %%
# Importing the train-test files

X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

X_train.head()
# Out:
#                                                                                      clean_text
# 0                                                                               ['You', 'like']
# 1  ['I', 'agree', 'So', 'stop', 'thinkin', 'ipad', 'Can', 'please', 'ask', 'macho', 'question']
# 2                                                            ['Kkwhere', 'youhow', 'performed']
# 3                                              ['Moji', 'informed', 'saved', 'lives', 'Thanks']
# 4                                  ['Its', 'okcome', 'home', 'vl', 'nice', 'meet', 'v', 'chat']

# %% [markdown]
# ## Vectorization

# %%
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
#

tfidf_vect.vocabulary_
# Out:
# {'you': 8347,
#  'like': 4432,
#  'agree': 955,
#  'so': 6736,
#  'stop': 6973,
#  'thinkin': 7360,
#  'ipad': 3996,
#  'can': 1769,
#  'please': 5660,
#  'ask': 1200,
#  'macho': 4628,
#  'question': 5950,
#  'kkwhere': 4260,
#  'youhow': 8353,
#  'performed': 5558,
#  'moji': 4909,
#  'informed': 3934,
#  'saved': 6367,
#  'lives': 4476,
#  'thanks': 7302,
#  'its': 4042,
#  'okcome': 5324,
#  'home': 3707,
#  'vl': 7860,
#  'nice': 5138,
#  'meet': 4757,
#  'chat': 1898,
#  'evening': 2844,
#  'good': 3387,
#  'somewhat': 6769,
#  'event': 2846,
#  'laden': 4308,
#  'will': 8086,
#  'fill': 3026,
#  'dont': 2586,
#  'worry': 8182,
#  'head': 3586,
#  'ok': 5322,
#  'throat': 7389,
#  'wrecked': 8200,
#  'see': 6430,
#  'six': 6652,
#  'my': 5031,
#  'love': 4553,
#  'how': 3759,
#  'come': 2067,
#  'took': 7502,
#  'long': 4513,
#  'leave': 4379,
#  'zahers': 8390,
#  'got': 3411,
#  'words': 8164,
#  'ym': 8339,
#  'happy': 3555,
#  'sad': 6317,
#  'left': 4384,
#  'miss': 4861,
#  'gettin': 3320,
#  'rdy': 6016,
#  'ship': 6544,
#  'comp': 2079,
#  'sorry': 6791,
#  'da': 2291,
#  'thangam': 7299,
#  'held': 3612,
#  'prasad': 5782,
#  'supposed': 7109,
#  'wake': 7908,
#  'me': 4738,
#  'gt': 3476,
#  'quite': 5958,
#  'bit': 1488,
#  'ex': 2872,
#  'better': 1453,
#  'go': 3361,
#  'eat': 2698,
#  'smth': 6726,
#  'else': 2750,
#  'ill': 3872,
#  'feel': 2991,
#  'guilty': 3496,
#  'right': 6224,
#  'meanwhile': 4746,
#  'hows': 3764,
#  'project': 5872,
#  'twins': 7622,
#  'comin': 2072,
#  'cause': 1838,
#  'im': 3875,
#  'freaky': 3172,
#  'lol': 4506,
#  'well': 8008,
#  'shes': 6536,
#  'big': 1466,
#  'surprise': 7119,
#  'your': 8362,
#  'b4u': 1293,
#  'voucher': 7872,
#  'wc': 7963,
#  '2703': 429,
#  'marsms': 4697,
#  'log': 4496,
#  'onto': 5358,
#  'wwwb4utelecom': 8232,
#  'discount': 2524,
#  'credit': 2229,
#  'to': 7451,
#  'opt': 5380,
#  'reply': 6150,
#  'customer': 2277,
#  'care': 1794,
#  'call': 1736,
#  '08717168528': 121,
#  '85233': 757,
#  'freeringtonereply': 3186,
#  'real': 6030,
#  'thats': 7319,
#  'fine': 3042,
#  'give': 3342,
#  'knows': 4270,
#  'wants': 7933,
#  'questions': 5952,
#  'daal': 2292,
#  'ltgt': 4582,
#  'howz': 3766,
#  'painit': 5457,
#  'todaydo': 7460,
#  'said': 6323,
#  'ystrdayice': 8379,
#  'medicine': 4753,
#  'we': 7966,
#  'new': 5122,
#  'local': 4489,
#  'dates': 2333,
#  'area': 1152,
#  'lots': 4541,
#  'people': 5551,
#  'registered': 6101,
#  'date': 2331,
#  'start': 6918,
#  '18': 356,
#  'wwwflirtpartyus': 8239,
#  'replys150': 6153,
#  'someone': 6756,
#  'know': 4267,
#  'asked': 1202,
#  'dating': 2334,
#  'service': 6479,
#  'contact': 2136,
#  'cant': 1781,
#  'guess': 3487,
#  '09058091854': 169,
#  'now': 5228,
#  'revealed': 6209,
#  'po': 5677,
#  'box385': 1592,
#  'm6': 4616,
#  '6wu': 682,
#  'no': 5167,
#  'working': 8171,
#  'ringing': 6230,
#  'thing': 7356,
#  'whole': 8063,
#  'houseful': 3754,
#  'screaming': 6404,
#  'brats': 1614,
#  'pulling': 5915,
#  'hair': 3518,
#  'loving': 4565,
#  'still': 6960,
#  'sir': 6637,
#  'send': 6459,
#  'group': 3465,
#  'mail': 4651,
#  'check': 1909,
#  'gd': 3291,
#  'lor': 4528,
#  'shopping': 6564,
#  'stuff': 7024,
#  'wan': 7924,
#  'watch': 7949,
#  'infernal': 3928,
#  'affairs': 924,
#  'lar': 4334,
#  'squeeeeeze': 6887,
#  'this': 7366,
#  'christmas': 1977,
#  'hug': 3792,
#  'if': 3859,
#  'lik': 4431,
#  'frndshp': 3213,
#  'den': 2417,
#  'back': 1308,
#  'get': 3313,
#  'cute': 2282,
#  'luvd': 4599,
#  'lucky': 4588,
#  'none': 5197,
#  'hate': 3570,
#  'reach': 6018,
#  'safe': 6319,
#  'sound': 6804,
#  'liao': 4407,
#  'aight': 970,
#  'plan': 5644,
#  'later': 4348,
#  'tonight': 7497,
#  'number': 5253,
#  'tomorrow': 7485,
#  'morning': 4947,
#  'cashbincouk': 1823,
#  'cash': 1821,
#  'weekend': 7995,
#  'wwwcashbincouk': 8234,
#  'dear': 2362,
#  'welcome': 8006,
#  'biggest': 1468,
#  'best': 1445,
#  'ever': 2848,
#  'away': 1280,
#  'these': 7346,
#  'hi': 3650,
#  'babe': 1297,
#  'uawakefeellikw': 7642,
#  'shitjustfound': 6552,
#  'out': 5413,
#  'via': 7825,
#  'aletter': 993,
#  'thatmum': 7317,
#  'gotmarried': 3414,
#  '4thnovbehind': 602,
#  'ourbacks': 5412,
#  'åð': 8402,
#  'fuckinniceselfish': 3228,
#  'work': 8167,
#  'something': 6763,
#  'sounds': 6806,
#  'when': 8043,
#  'want': 7929,
#  'rather': 6003,
#  'prominent': 5876,
#  'bite': 1491,
#  'mark': 4687,
#  'cheek': 1915,
#  'hey': 3646,
#  'tmr': 7446,
#  'bugis': 1680,
#  '930': 806,
#  'phone': 5597,
#  'weirdest': 8004,
#  'auto': 1257,
#  'correct': 2171,
#  'docs': 2552,
#  'appointments': 1129,
#  'next': 5132,
#  'week': 7993,
#  'tired': 7428,
#  'shoving': 6581,
#  'ugh': 7648,
#  'couldnt': 2190,
#  'normal': 5206,
#  'body': 1542,
#  'okie': 5328,
#  'bishan': 1487,
#  'cos': 2176,
#  'driving': 2641,
#  'today': 7458,
#  'theres': 7344,
#  'point': 5697,
#  'hangin': 3540,
#  'mr': 4974,
#  'hes': 3641,
#  'makin': 4661,
#  'attend': 1236,
#  'sending': 6462,
#  'mental': 4784,
#  'ability': 832,
#  'wanna': 7927,
#  'laid': 4315,
#  '2nite': 465,
#  'dogging': 2566,
#  'locations': 4491,
#  'sent': 6468,
#  'direct': 2506,
#  'ur': 7741,
#  'mobile': 4894,
#  'join': 4122,
#  'uks': 7658,
#  'largest': 4338,
#  'network': 5114,
#  'txt': 7625,
#  'park': 5491,
#  '69696': 661,
#  'nyt': 5268,
#  'ec2a': 2703,
#  '3lp': 528,
#  '150msg': 320,
#  'anything': 1100,
#  'valuable': 7793,
#  'situations': 6649,
#  'first': 3058,
#  'before': 1416,
#  'getting': 3321,
#  'second': 6418,
#  'after': 935,
#  'loosing': 4526,
#  'and': 1058,
#  'time': 7417,
#  'also': 1023,
#  'tried': 7567,
#  'adding': 893,
#  'zeros': 8393,
#  'that': 7311,
#  'savings': 6369,
#  'the': 7322,
#  'checking': 1913,
#  'solve': 6750,
#  'case': 1820,
#  'man': 4667,
#  'was': 7942,
#  'found': 3155,
#  'murdered': 5018,
#  'on': 5343,
#  'ltdecimalgt': 4580,
#  'afternoon': 937,
#  '1his': 369,
#  'wife': 8075,
#  'called': 1749,
#  'police': 5702,
#  '2police': 470,
#  'questioned': 5951,
#  'everyone': 2854,
#  '3wife': 541,
#  'siri': 6638,
#  'sleeping': 6675,
#  'murder': 5017,
#  'place': 5638,
#  '4cook': 583,
#  'cooking': 2160,
#  '5gardener': 626,
#  'picking': 5611,
#  'vegetables': 7811,
#  '6housemaid': 673,
#  'went': 8016,
#  'post': 5743,
#  'office': 5300,
#  '7children': 700,
#  'play': 5650,
#  '8neighbour': 799,
#  'marriage': 4693,
#  'arrested': 1179,
#  'murderer': 5019,
#  'immediately': 3884,
#  'whos': 8065,
#  'it': 4024,
#  'with': 8115,
#  'reason': 6042,
#  'brilliant': 1636,
#  'free': 3174,
#  'entry': 2799,
#  'wkly': 8128,
#  'win': 8089,
#  'fa': 2922,
#  'cup': 2265,
#  'final': 3035,
#  'tkts': 7440,
#  '21st': 407,
#  'may': 4730,
#  '2005': 395,
#  'text': 7283,
#  '87121': 769,
#  'receive': 6056,
#  'questionstd': 5953,
#  'ratetcs': 6002,
#  'apply': 1124,
#  '08452810075over18s': 64,
#  'ive': 4052,
#  'told': 7475,
#  'returned': 6204,
#  'order': 5393,
#  'many': 4679,
#  'returns': 6206,
#  'day': 2343,
#  'wish': 8107,
#  'birthday': 1486,
#  'gorgeous': 3407,
#  'have': 3576,
#  'one': 5347,
#  'squishy': 6890,
#  'mwahs': 5030,
#  'unni': 7707,
#  'thank': 7301,
#  'rechargerakhesh': 6066,
#  'oops': 5364,
#  'mums': 5011,
#  'somerset': 6761,
#  'far': 2960,
#  'tomo': 7482,
#  'soon': 6781,
#  'gonna': 3385,
#  'much': 4995,
#  'hurry': 3816,
#  'soup': 6808,
#  'done': 2583,
#  'hope': 3727,
#  'things': 7358,
#  'doctors': 2554,
#  'reminds': 6128,
#  'need': 5093,
#  '2godid': 451,
#  'little': 4471,
#  'lounge': 4549,
#  'whatever': 8037,
#  'juliana': 4153,
#  'do': 2546,
#  'treasure': 7557,
#  'every': 2849,
#  'moment': 4914,
#  'spend': 6844,
#  'together': 7468,
#  'online': 5353,
#  'night': 5146,
#  'message': 4798,
#  'important': 3889,
#  'information': 3933,
#  'o2': 5272,
#  'user': 7762,
#  'find': 3039,
#  'httpwwwurawinnercom': 3785,
#  'fantastic': 2958,
#  'awaiting': 1276,
#  'barred': 1347,
#  'stores': 6985,
#  'lifethis': 4421,
#  'twat': 7616,
#  'orange': 5389,
#  'dungerees': 2672,
#  'came': 1765,
#  'wanted': 7931,
#  'decking': 2383,
#  'punch': 5918,
#  'thatll': 7316,
#  'ron': 6261,
#  'say': 6371,
#  'fri': 3196,
#  'leh': 4389,
#  'ding': 2500,
#  'tai': 7174,
#  'feng': 3001,
#  'make': 4659,
#  'reservations': 6167,
#  'but': 1703,
#  'wait': 7901,
#  'unlimited': 7704,
#  'texts': 7294,
#  'limited': 4442,
#  'minutes': 4852,
#  'hello': 3617,
#  'goes': 3371,
#  'job': 4115,
#  'prospects': 5893,
#  'boytoy': 1605,
#  'teasing': 7239,
#  'kiss': 4243,
#  'takes': 7182,
#  'take': 7178,
#  'part': 5496,
#  'wrc': 8199,
#  'rally': 5987,
#  'oz': 5443,
#  'lucozade': 4589,
#  'energy': 2777,
#  'le': 4369,
#  '61200': 646,
#  '25p': 423,
#  'packs': 5449,
#  'lucozadecoukwrc': 4590,
#  'itcould': 4027,
#  'compliments': 2094,
#  'system': 7160,
#  'side': 6605,
#  'never': 5118,
#  'blame': 1501,
#  'life': 4418,
#  'days': 2347,
#  'happiness': 3554,
#  'bad': 1312,
#  'experience': 2899,
#  'both': 1573,
#  'essential': 2827,
#  'all': 1004,
#  'gods': 3370,
#  'blessings': 1513,
#  'oh': 5315,
#  'year': 8309,
#  'yetunde': 8336,
#  'didnt': 2473,
#  'money': 4921,
#  'mid': 4820,
#  'january': 4077,
#  'return': 6203,
#  'period': 5562,
#  'ended': 2771,
#  'reache': 6019,
#  'room': 6263,
#  'friends': 3202,
#  'late': 4344,
#  'arpraveesh': 1175,
#  'details': 2448,
#  'face': 2925,
#  'book': 1553,
#  'delicious': 2409,
#  'treat': 7558,
#  'are': 1151,
#  'alright': 1020,
#  'think': 7359,
#  'sweet': 7137,
#  'jolt': 4133,
#  'heart': 3599,
#  'remind': 6124,
#  'hear': 3595,
#  'screamed': 6403,
#  'across': 872,
#  'sea': 6412,
#  'world': 8174,
#  'ahmad': 963,
#  'al': 983,
#  'hallaq': 3526,
#  'loved': 4555,
#  'owned': 5439,
#  'possessive': 5738,
#  'passionate': 5512,
#  'height': 3611,
#  'recycling': 6078,
#  'read': 6024,
#  'twice': 7619,
#  'earning': 2690,
#  'spent': 6846,
#  'spending': 6845,
#  'keep': 4201,
#  'smiling': 6711,
#  'eyes': 2920,
#  'philosophy': 5594,
#  'yup': 8386,
#  'coffee': 2040,
#  'wif': 8074,
#  'frens': 3191,
#  'fren': 3189,
#  'drove': 2647,
#  'shell': 6533,
#  'lift': 4425,
#  'coming': 2073,
#  'dinner': 2502,
#  'rite': 6239,
#  'dad': 2296,
#  'confirm': 2114,
#  'since': 6628,
#  'fever': 3005,
#  'vomitin': 7869,
#  'early': 2688,
#  'lei': 4391,
#  'outside': 5423,
#  'wun': 8225,
#  'neva': 5117,
#  'mind': 4835,
#  'just': 4161,
#  'type': 7637,
#  'food': 3117,
#  'boo': 1551,
#  'bored': 1564,
#  'already': 1018,
#  'shower': 6584,
#  'parking': 5495,
#  'garage': 3269,
#  'collapsed': 2051,
#  'university': 7700,
#  'hospital': 3741,
#  'crazy': 2222,
#  'does': 2558,
#  'happen': 3545,
#  'yo': 8341,
#  'way': 7961,
#  'could': 2188,
#  'pick': 5609,
#  'why': 8067,
#  'nothing': 5218,
#  'anyway': 1103,
#  'oredi': 5395,
#  'somebody': 6754,
#  'set': 6483,
#  'website': 7982,
#  'hold': 3698,
#  'em': 2753,
#  'using': 7767,
#  'eve': 2840,
#  'spacebucks': 6817,
#  'wot': 8189,
#  'wed': 7984,
#  'nite': 5163,
#  'til': 7414,
#  'fyi': 3249,
#  'usf': 7764,
#  'swing': 7145,
#  'whenever': 8044,
#  'always': 1029,
#  'convincing': 2156,
#  'pls': 5667,
#  'boy': 1600,
#  'glad': 3347,
#  'wasted': 7946,
#  'applebees': 1122,
#  'congratulations': 2121,
#  'friend': 3200,
#  'won': 8147,
#  '2000': 391,
#  'xmas': 8280,
#  'prize': 5842,
#  'claim': 1986,
#  'easy': 2697,
#  '08718726971': 135,
#  'only': 5356,
#  '10p': 278,
#  'per': 5552,
#  'minute': 4851,
#  'btnationalrate': 1669,
#  'sporadically': 6870,
#  'starting': 6921,
#  'bc': 1377,
#  'doin': 2569,
#  'shit': 6549,
#  'enjoy': 2783,
#  'watching': 7953,
#  'playing': 5656,
#  'football': 3122,
#  'basketball': 1356,
#  'outdoors': 5416,
#  'rtking': 6287,
#  'pro': 5845,
#  'video': 7831,
#  'club': 2023,
#  'help': 3622,
#  'inforingtonekingcouk': 3931,
#  '08701237397': 68,
#  'must': 5024,
#  '16': 352,
#  'credits': 2231,
#  'redeemable': 6080,
#  'wwwringtonekingcouk': 8251,
#  'senthil': 6471,
#  'company': 2082,
#  'apnt': 1111,
#  '5pm': 634,
#  'tbspersolvo': 7220,
#  'chasing': 1897,
#  'us': 7754,
#  'sept': 6473,
#  'forå': 3154,
#  '38': 517,
#  'definitely': 2398,
#  'paying': 5531,
#  'ignore': 3864,
#  'kath': 4192,
#  'manchester': 4672,
#  'pretty': 5818,
#  'pissed': 5632,
#  'class': 1994,
#  'did': 2472,
#  'by': 1716,
#  'rencontre': 6132,
#  'mountains': 4963,
#  'different': 2487,
#  'wonder': 8149,
#  'able': 835,
#  'show': 6582,
#  'value': 7794,
#  'continue': 2144,
#  'brisk': 1643,
#  'walks': 7917,
#  'drugs': 2651,
#  'without': 8118,
#  'askin': 1203,
#  'laugh': 4353,
#  'dearly': 2367,
#  'problem': 5848,
#  'promise': 5877,
#  'princess': 5830,
#  'run': 6301,
#  'pics': 5613,
#  'chance': 1874,
#  'ttyl': 7600,
#  'sms': 6720,
#  'ac': 846,
#  'sptv': 6882,
#  'jersey': 4100,
#  'devils': 2454,
#  'detroit': 2450,
#  'red': 6079,
#  'wings': 8098,
#  'ice': 3843,
#  'hockey': 3696,
#  'incorrect': 3913,
#  'end': 2770,
#  'person': 5570,
#  'survey': 7121,
#  'goin': 3373,
#  'hadnt': 3511,
#  'put': 5932,
#  'clocks': 2010,
#  'shouted': 6578,
#  'realised': 6033,
#  'wahay': 7897,
#  'another': 1080,
#  'hour': 3750,
#  'bed': 1402,
#  'loosu': 4527,
#  'de': 2355,
#  'let': 4402,
#  'careless': 1801,
#  'hon': 3712,
#  'lab': 4302,
#  'skallis': 6657,
#  'wont': 8153,
#  'two': 7624,
#  'odi': 5289,
#  'posible': 5733,
#  'dnt': 2545,
#  'live': 4472,
#  'century': 1860,
#  'cm': 2024,
#  'frwd': 3222,
#  'thnk': 7371,
#  'smile': 6707,
#  'pleasure': 5662,
#  'pain': 5455,
#  'trouble': 7573,
#  'pours': 5758,
#  'rain': 5976,
#  'sum1': 7078,
#  'hurts': 3819,
#  'becoz': 1400,
#  'loves': 4563,
#  'nah': 5044,
#  'car': 1789,
#  'meant': 4745,
#  'crammed': 2213,
#  'full': 3233,
#  'luv': 4598,
#  'soo': 6780,
#  'donåõt': 2590,
#  'understand': 7678,
#  'special': 6828,
#  'ring': 6229,
#  '2morrow': 459,
#  'xxx': 8288,
#  'daddy': 2297,
#  'scream': 6402,
#  'going': 3374,
#  'slap': 6671,
#  'ass': 1209,
#  'dick': 2469,
#  'attended': 1237,
#  'guaranteed': 3479,
#  '1000': 261,
#  'yr': 8377,
#  'representative': 6156,
#  '08714712394': 109,
#  '10am7pm': 275,
#  'tmobile': 7444,
#  'camera': 1766,
#  'upgrade': 7726,
#  'pay': 5527,
#  'sim': 6622,
#  'card': 1790,
#  'loyalty': 4573,
#  '0845': 60,
#  '021': 13,
#  '3680offer': 514,
#  'ends': 2774,
#  '28thfebtcs': 436,
#  'hiya': 3679,
#  'spoken': 6865,
#  'sleep': 6673,
#  'great': 3444,
#  'feeling': 2993,
#  'opportunity': 5375,
#  'last': 4341,
#  'thought': 7380,
#  'what': 8036,
#  'looking': 4521,
#  'joys': 4143,
#  'father': 2971,
#  'john': 4120,
#  'then': 7335,
#  'name': 5050,
#  'mandan': 4674,
#  'nokia': 5188,
#  '3510i': 509,
#  'colour': 2061,
#  'delivered': 2411,
#  '200': 390,
#  '100': 260,
#  'camcorder': 1764,
#  '8000930705': 709,
#  'space': 6816,
#  'gives': 3344,
#  'everything': 2858,
#  'remember': 6119,
#  'furniture': 3244,
#  'around': 1173,
#  'move': 4966,
#  'lock': 4493,
#  'locks': 4494,
#  'key': 4214,
#  'jenne': 4094,
#  'cock': 2035,
#  'hubbys': 3790,
#  'satisfy': 6359,
#  '89938': 793,
#  'strings': 7003,
#  'action': 877,
#  'rec': 6051,
#  '150ea': 318,
#  'otbox': 5406,
#  '731': 690,
#  'la1': 4299,
#  '7ws': 706,
#  'babes': 1298,
#  'brolly': 1652,
#  'english': 2782,
#  'wil': 8082,
#  'bring': 1640,
#  '2mrw': 461,
#  'franxx': 3166,
#  'moby': 4902,
#  'pub': 5909,
#  'quizwin': 5962,
#  'high': 3656,
#  'street': 6996,
#  'duchess': 2662,
#  'cornwall': 2169,
#  '82277unsub': 730,
#  '150': 316,
#  '008704050406': 0,
#  'sp': 6815,
#  'hungry': 3807,
#  'gay': 3280,
#  'guys': 3501,
#  '08718730555': 140,
#  '10pmin': 279,
#  '08712460324': 102,
#  'as': 1191,
#  'usualiam': 7774,
#  'amp': 1046,
#  'thanx': 7307,
#  'private': 5839,
#  '2003': 393,
#  'account': 861,
#  'statement': 6926,
#  'shows': 6589,
#  '800': 708,
#  'unredeemed': 7709,
#  'points': 5698,
#  '08718738001': 142,
#  'identifier': 3853,
#  'code': 2038,
#  '49557': 581,
#  'expires': 2904,
#  '261104': 426,
#  'themobhit': 7332,
#  'link': 4453,
#  'premium': 5799,
#  'pink': 5627,
#  'panther': 5468,
#  'game': 3261,
#  'sugababes': 7068,
#  'zebra': 8391,
#  'animation': 1067,
#  'badass': 1313,
#  'hoody': 3722,
#  'wallpaperall': 7920,
#  'review': 6211,
#  'ngage': 5133,
#  'deck': 2382,
#  'wwwcnupdatescomnewsletter': 8236,
#  'unsubscribe': 7714,
#  'alerts': 992,
#  'word': 8161,
#  'sch': 6384,
#  'fr': 3161,
#  '46': 575,
#  'dun': 2671,
#  'haf': 3512,
#  'cold': 2047,
#  'indians': 3923,
#  'poor': 5720,
#  'india': 3921,
#  'country': 2195,
#  'says': 6375,
#  'swiss': 7146,
#  'bank': 1336,
#  'directors': 2509,
#  'he': 3585,
#  'lac': 4304,
#  'crore': 2242,
#  'indian': 3922,
#  'deposited': 2426,
#  'banks': 1337,
#  'used': 7759,
#  'taxless': 7214,
#  'budget': 1676,
#  'yrs': 8378,
#  'jobs': 4116,
#  'from': 3218,
#  'village': 7843,
#  'delhi': 2408,
#  'lane': 4326,
#  'roads': 6243,
#  'forever': 3132,
#  'power': 5760,
#  'suply': 7100,
#  'social': 6740,
#  'projects': 5873,
#  'citizen': 1983,
#  'monthly': 4934,
#  'imf': 3882,
#  'loan': 4486,
#  'blocked': 1517,
#  'rich': 6221,
#  'politicians': 5703,
#  'rights': 6227,
#  'corrupt': 2174,
#  'itna': 4037,
#  'forward': 3152,
#  'karo': 4190,
#  'ki': 4220,
#  'pura': 5920,
#  'padhegm': 5450,
#  'urgent': 7744,
#  '09066612661': 238,
#  'landline': 4321,
#  '5000': 610,
#  'luxury': 4602,
#  'canary': 1772,
#  'islands': 4018,
#  'holiday': 3702,
#  'await': 1275,
#  'collection': 2056,
#  'tcs': 7224,
#  'sae': 6318,
#  'award': 1278,
#  '20m12aq': 400,
#  '150ppm': 336,
#  'ûï': 8411,
#  'hopeing': 3732,
#  'gone': 3382,
#  'sisters': 6642,
#  'ya': 8296,
#  'ready': 6028,
#  'thursday': 7401,
#  'even': 2843,
#  'convincingjust': 2157,
#  'tel': 7248,
#  'neglect': 5102,
#  'msgs': 4983,
#  'itjust': 4032,
#  'meeting': 4760,
#  'wahala': 7896,
#  'reached': 6020,
#  'yesim': 8330,
#  'ringtone': 6232,
#  'reference': 6086,
#  'x29': 8271,
#  'charged': 1887,
#  '450': 571,
#  'should': 6575,
#  'tone': 7489,
#  'arrive': 1181,
#  'services': 6480,
#  '09065989180': 221,
#  'possible': 5741,
#  'teach': 7230,
#  'urgnt': 7748,
#  'whats': 8038,
#  'least': 4376,
#  'tell': 7252,
#  'wating': 7956,
#  'she': 6528,
#  'wondering': 8151,
#  'coping': 2165,
#  'distance': 2531,
#  'level': 4406,
#  'series': 6475,
#  'means': 4744,
#  'record': 6071,
#  'flood': 3089,
#  'pussy': 5931,
#  'cum': 2263,
#  'opinion': 5372,
#  'over': 5427,
#  'jada': 4066,
#  ...}

# %%
# Storing the Matrices

X_test_vect[0]
# Out:
# <1x8415 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>

# %%
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ## Building the Model

# %%
rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluating the Model

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print("Precision: {} -- Recall: {} -- Accuracy: {}".format(precision,
                                                          round(recall, 3),
                                                            round((y_test['label'] == y_pred).sum() / len(y_pred), 3)))
# Out:
# Precision: 1.0 -- Recall: 0.872 -- Accuracy: 0.984
